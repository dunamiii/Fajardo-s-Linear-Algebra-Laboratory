# %% [markdown]
# # Linear Algebra for CpE
# ## Laboratory 3 : Linear Combination and Vector Spaces

# %% [markdown]
# Now that you have a fundamental knowledge about linear combination, we'll try to visualize it using scientific programming.

# %% [markdown]
# ### Objectives
# At the end of this activity you will be able to:
# 1. Be familiar with representing linear combinations in the 2-dimensional plane.
# 2. Visualize spans using vector fields in Python.
# 3. Perform vector fields operations using scientific programming.

# %% [markdown]
# ## Discussion

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Linear Combination

# %% [markdown]
# It is said that a linear combination is the combination of linear scaling and addition of a vector its bases/components

# %% [markdown]
# We will try to visualize the vectors and their linear combinations by plotting a sample of real number values for the scalars for the vectors. Let's first try the vectors below:

# %% [markdown]
# $$X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
vectX =  np.array([5,5])
vectY =  np.array([7,9])

# %% [markdown]
# #### Span of single vectors

# %% [markdown]
# As discussed in the lecture, the span of individual vectors can be represented by a line span. Let's take vector $X$ as an example.

# %% [markdown]
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$

# %%
c = np.arange(-10,10,0.25)

plt.scatter(c*vectX[0],c*vectX[1])

plt.scatter(c*vectY[0],c*vectY[1])


plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### Span of a linear combination of vectors

# %% [markdown]
# So what if we are to plot the span of a linear combination of vectors? We can visualize as a plane on the 2-dimensional coordinate system. Let's take the span of the linear combination below:

# %% [markdown]
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([1,0])
vectB = np.array([1,-1])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)
#vectR = vectA + vectB

spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]

# plt.scatter(R*vectA[0],R*vectA[1])
plt.scatter(spanRx,spanRy, s=5, alpha=1)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# Take note that if vectors are seen to be as a 2-dimensional span we can say it has a Rank of 2 or $\mathbb{R}^2$. But if the span of the linear combination of vectors are seen to be like a line, they are said to be <b> linearly dependent </b> and they have a rank of 1 or $\mathbb{R}^1$.

# %% [markdown]
# # Activity

# %% [markdown]
# ### Task 1

# %% [markdown]
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the  linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# $$ VectorX = 2x + y $$
# $$ VectorY = 8x + 7y $$

# %% [markdown]
# $$X = \begin{bmatrix} 2\\8 \\\end{bmatrix} , Y = \begin{bmatrix} 1\\7 \\\end{bmatrix} $$

# %%
VectX= np.array([2,8]) #Value of vector 1
VectY= np.array([1,7])  #Value of Vector 2

s = np.arange(-10,10,0.5) #Makes the points of plot arranged

plt.scatter(s*VectX[0],s*VectY[0]) #Plotting style used scatter.
plt.scatter(s*VectX[1],s*VectY[1]) #VectorX and Y plot 

plt.xlim(-10,10) #limit of x-axis in plotting
plt.ylim(-10,10) #Limit of y-axis in plotting

plt.axhline(y=0, color='k') #Color of the x-axis
plt.axvline(x=0, color='k') #Color of the y-axis
plt.grid() #Shows the grid
plt.plot() #shows the plot
# Out:
# []

# %% [markdown]
# ## Flowchart:
# ![Lab3_task1.png](attachment:Lab3_task1.png)

# %% [markdown]
# ### Task 2

# %% [markdown]
# Try making three unque spans using different linear combinations . In your methodology discuss the different functions that you have used, the  linear equations and vector form of span, and the flowchart for declaring and displaying span. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the span visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# $$ VectorX = 3x - 5y $$
# $$ VectorY = 2x + y $$

# %% [markdown]
# $$S = \begin{Bmatrix} m_1 \cdot\begin{bmatrix} 3\\-5 \\\end{bmatrix},
# m_2 \cdot \begin{bmatrix} 2\\1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
VectX= np.array([3,-5]) #Value of Vector 1
VectY= np.array([2,1]) #Value of Vector 2


R = np.arange(-10,2,0.5) #Makes the point of plot arranged
m1,m2 = np.meshgrid(R,R) #Shows all possible points of the linear combinations

spanRx = m1*VectX[0] + m2*VectY[0] #Shows the span of the first vector
spanRy = m1*VectX[1] + m2*VectY[1] #shows the span of the second vector


plt.scatter(spanRx,spanRy, s=5, alpha=0.5) #Plotting style used is scatter

plt.axhline(y=0, color='k') #Color of the x-axis
plt.axvline(x=0, color='k') #color of the y-axis

plt.grid() #shows the grid
plt.plot() #shows the plot
# Out:
# []

# %% [markdown]
# ## Flowchart:
# ![Lab3_Task%202.png](attachment:Lab3_Task%202.png)

# %% [markdown]
# ### 2nd Span
#
# $$ VectorX = 5x + 5y $$
# $$ VectorY = -6x + 5y $$
#
# $$S = \begin{Bmatrix} m_1 \cdot\begin{bmatrix} 5\\5 \\\end{bmatrix},
# m_2 \cdot \begin{bmatrix} -6\\5 \\\end{bmatrix}\end{Bmatrix} $$

# %%
VectX= np.array([5,5])
VectY= np.array([-6,5])


R = np.arange(-10,2,0.5)
m1,m2 = np.meshgrid(R,R)

spanRx = m1*VectX[0] + m2*VectY[0]
spanRy = m1*VectX[1] + m2*VectY[1] 


plt.scatter(spanRx,spanRy, s=5, alpha=0.5, color='r')

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

plt.grid() 
plt.plot()
# Out:
# []

# %% [markdown]
# ### 3rd Span
# $$ VectorX = -3x - 5y $$
# $$ VectorY = 2x + 4y $$
#
#
# $$S = \begin{Bmatrix} m_1 \cdot\begin{bmatrix} -3\\-5 \\\end{bmatrix},
# m_2 \cdot \begin{bmatrix} 2\\4 \\\end{bmatrix}\end{Bmatrix} $$

# %%
VectX= np.array([-3,-5])
VectY= np.array([2,4])


R = np.arange(-10,2,0.5)
m1,m2 = np.meshgrid(R,R)

spanRx = m1*VectX[0] + m2*VectY[0]
spanRy = m1*VectX[1] + m2*VectY[1] 


plt.scatter(spanRx,spanRy, s=5, alpha=0.5, color='g')

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

plt.grid() 
plt.plot()
# Out:
# []

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# Append your discussion at the end of the results section of your report just before your conclusion. Try to answer the following questions. Do not forget to cite your sources.

# %% [markdown]
# <br>1. You might have notices that the dimensions plot of linear combinations change according to its rank. If a vector is $\mathbb{R}=1$ the plot of its linear combination is one-dimensional or a line, and if $\mathbb{R}=2$ the plot is a plane. What will be the shape of the vector visualization if $\mathbb{R} = 3$ and if $\mathbb{R} = 4$?
#
# <br>When plotting the first and second vector if they are in the same direction, we can then span a line. Same with adding one more vector. If it is the same direction with the 2 vectors, we can only then span a line. If the second vector is in different direction than the first vector, we can span a plane. Adding a third vector that has the same direction, we still span a plane. But if it is with different direction we will span a 3D space[1]. Where a new axis, will be used. While the x-axis and y-axis is horizantal to each other. The Z-axis is vertical from the origin. It is determined by the right hand rule[2].<br>
#  For a rank 4, we will span a 4D space. A 2D dimensional can be visualize as a square, 3D will be a cube and 4D Dimensional is a tesseract[3].
#
#
#
# <br>2. Kindly discuss the role of unit vectors in relation to linear combinations.<br>
# The role of unit vectors in relation to linear combinations is to visualize how a set of ordered pairs will be on the plot. The vectors will be determined from the linear combinations and on how they will behave on the graph. And as for the Vectors, for every vectors it is equivalent to one linear combinations. So any vector you can see on the plane can be written as a linear combinations.
#
#
# ### References:
# [1] “linear algebra - Visualization of span of 3 vectors? - Mathematics Stack Exchange.” https://math.stackexchange.com/questions/1210897/visualization-of-span-of-3-vectors (accessed Oct. 23, 2020). <br>
# [2] “Three-Dimensional Coordinate Systems.” <br>
# [3] “Four dimensions.” https://www.pitt.edu/~jdnorton/teaching/HPS_0410/chapters/four_dimensions/index.html (accessed Oct. 23, 2020).

# %% [markdown]
# ## Conclusion guide

# %% [markdown]
# For your conclusion synthesize the concept and application of the laboratory. Briefly discuss what you have learn and achieved in this activity. At the end of your conclusion try to answer the question : "How can you apply the concept of linear combination in engineeing or real-life situations?".
