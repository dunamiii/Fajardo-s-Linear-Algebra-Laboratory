# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

# %%
def track_eagle(make_figs=True):
    long = np.random.randint(-10,10, size=10) ## since we don't actually have eagle tracking data we will use
    lat = np.random.randint(-10,10, size=10)  ## random integers for this activity. These two lines will produce
                                             ## a vector with shape of (3,) describing the distances for the 
                                             ## eagle's flight.

    dist1 = np.array ([long[9],lat[2]])      ## setup the array for each vector for the eagle's flight.
    dist2 = np.array ([long[5],lat[8]])
    dist3 = np.array ([long[2],lat[4]])
    dist_total = dist1 + dist2 + dist3       ## compute for the resultant vector for the eagle's flight.
   
    disp = np.linalg.norm(dist_total)                              ## compute for the magnitude of the displacement
    alpha = 10**-6
    theta =  np.arctan((dist_total[1]))/(dist_total[0]+alpha)       ## compute for the angle of the displacement. Hint
    theta = np.degrees(theta)                ## convert theta from rad to deg.
    
    ## Plotting the PH Eagle flight vectors.
    plt.figure(figsize=(10,10))
    plt.title('Philippine Eagle Flight Plotter')
    plt.xlim(-30, 30)
    plt.ylim(-30, 30)
    plt.xlabel('Latitudinal Distance')
    plt.ylabel('Longitudinal Distance')
    plt.grid()
    n = 2
    
    ### Self-discovery code block (Refer to guide question 2 for the task)
    
    plt.quiver(0,0, dist1[0], dist1[1], 
               angles='xy', scale_units='xy',scale=1, color='red', 
               label='Trajectory 1: {:.2f}m.'.format(np.linalg.norm(dist1)))
    plt.quiver(dist1[0], dist1[1], dist2[0], dist2[1], 
               angles='xy', scale_units='xy',scale=1, color='blue',
              label='Trajectory 2: {:.2f}m.'.format(np.linalg.norm(dist2)))
    plt.quiver(np.add(dist1[0],dist2[0]), np.add(dist1[1],dist2[1]),
               dist3[0], dist3[1], angles='xy', scale_units='xy',scale=1, color='green',
              label='Trajectory 3: {:.2f}m.'.format(np.linalg.norm(dist3)))
    plt.quiver(0,0, dist_total[0], dist_total[1], 
               angles='xy', scale_units='xy',scale=1, color='orange',
              label='Displacement: {:.2f}m. @ {:.2f}'.format(disp, theta))
    
    plt.legend()
    
    if make_figs:
        plt.savefig(f'LinAlg-Lab2-PH Eagle-{int(disp)}@{int(theta)}.png', dpi=300)
    
    plt.show()

# %%
track_eagle(make_figs=False) ## Let 'make_figs' equal to False during debugging.

# %% [markdown]
# **Guide questions:**
# 1. What is the use of the variable  α ?
#    <br> The variable α or alpha is used as a placeholder for the element for the vectors.
#
# 2. Kindly explain the process of plotting the eagle flight vectors.
#    <br> The function used to plot is quiver and mathplotlib. Mathplotlib is a library that used for visualization, for plotting 2D arrays[1]. While quiver is used as auto scaling for the vectors[2]. The value in the array is used for the plot. Langtitude and longtitude size is set for the limit of the array. The 4th vector is represented as the resultant of the three vector. The plotting is based on the value of the array.
#
# 3. Provide a flow chart describing the 'track_eagle' function. Please use LucidCharts or similar apps in making charts.
# ![Eagle%20Tracker.png](attachment:Eagle%20Tracker.png)
#
# **Screenshots**
#
# ![eagle%202.PNG](attachment:eagle%202.PNG)![eagle%201.PNG](attachment:eagle%201.PNG)![eagle%204.PNG](attachment:eagle%204.PNG)![eagle%203.PNG](attachment:eagle%203.PNG)
#
# Note: provide 4 screenshots of the "Philippine Eagle Flight Plotter" figure.

# %%
'''
GRADED CELL 2 (20 points)
This code models a bad practice among software engineers. The code exhibits a lack of documentation, comments, and vague
variable declarations. Aside from explaining and deconstructing the code, make an appropriate documentation as a markdown,
proper comments for significant lines of code, and changing variable names into easily-understood naming.
'''
import numpy as np
def eagle_motion(velocity, speed): # Function of the eagle's motion with parameters named velocity and speed
    eagle_form = 4                 # the shape of the eagle; visualization
    movement1 = np.zeros((eagle_form-1,)) # initializing the array of the eagle_form for its 1st movement
    movement2= np.zeros((eagle_form-2,))  # initializing the array of the eagle_form for its 2nd movement
    Direction = np.array([speed**3, speed**2, speed, 1]) # # array of the direction using time
   
    if  velocity.shape == (eagle_form,): # conditional statement for the eagle_form
        movement1 = np.array([3*velocity[0],2*velocity[1], velocity[2]]) # getting the array for movement1
        movement2 = np.array([2*movement1[0],movement1[1]])     # getting the array for movement2
        velocity_total = np.sum(np.multiply(speed, Direction))  # getting the velocity by multiplying the speed and direction 
        movement1_total = np.sum(np.multiply(movement1, Direction[1:])) # Final position of the movement 1
        movement2_total = np.sum(np.multiply(movement2, Direction[2:])) # Final position of the movement 2
        
    else:
        print(f'Input displacement vector is not valid. Make sure that the vector shape is ({eagle_form},)')
    
    return velocity_total, movement1_total, movement2_total # return value of the function under conditional statement

# %%
velocity = np.array([2,1,3,2])
speed = 2
eagle_motion (velocity, speed)
# Out:
# (30, 31, 26)

# %% [markdown]
# # **Guide questions:**
# 1. What is the function for? Explain the inputs, process, functions used, and the outputs.
#     <br> The function of eagle_motion is to track the eagle's motion. The parameters is called velocity and speed. The vector is named as eagle_form. The movement 1 & 2 is used to get the array of the movement of the eagle. The velocity_total, movement1_total and movement2_total used equation to get the result of the arrays and be able to come up values for plotting. These three as well were returned because these will be shown when the eagle_motion were called. Using the function, the values for the parameters of the eagle_motion were set, then calling the function The output will show the result of the computed values given. <br>
#
# 2. Kindly provide equations for  st , vt , and  at  basing on their code.
#     $$ velocity_t\ = [[speed] x [direction]] $$ <br>
#     $$ movement1_t\ = [[movement1]x[Direction(1)]] $$ <br>
#     $$ movement2_t\ = [[movement2]x[Direction(2)]] $$ <br>
#
# 3. Re-type the 'eagle_kinematics' function in your jupyter notebook. Write a brief description of the function before the code cell in a markdown. Include the equations from (2.). <br>
# <br> import numpy as np
#    <br> def eagle_motion(velocity, speed): # Function of the eagle's motion with parameters named velocity and speed
#     <br>eagle_form = 4                 # the shape of the eagle; visualization
#     <br>movement1 = np.zeros((eagle_form-1,)) #initializing the array of the eagle_form for its 1st movement
#     <br>movement2= np.zeros((eagle_form-2,))  #initializing the array of the eagle_form for its 2nd movement
#     <br>Direction = np.array([speed**3, speed**2, speed, 1]) #array of the direction using time
#     <br>
# <br>    if  velocity.shape == (eagle_form,): # conditional statement for the eagle_form
# <br>        movement1 = np.array([3*velocity[0],2*velocity[1], velocity[2]]) # getting the array for movement1
# <br>        movement2 = np.array([2*movement1[0],movement1[1]])     # getting the array for movement2 <br>
#
#
# <br> **This function calculate the value inputed in speed and direction by multiplying it** <br>
#         $$ velocity_t\ = [[speed] x [direction]] $$ <br>
#         velocity_total = np.sum(np.multiply(speed, Direction))  # getting the velocity by multiplying the speed and direction <br>
#
# <br> **This function calculate the value inputed in movement1 and direction by multiplying it**
#        $$ movement1_t\ = [[movement1]x[Direction(1)]] $$ <br>
#        movement1_total = np.sum(np.multiply(movement1, Direction[1:])) # Final position of the movement 1 <br>
#
#
# <br> **This function calculate the value inputed in movement2 and direction by multiplying it** <br>
#         $$ movement2_t\ = [[movement2]x[Direction(2)]] $$ <br>
#         movement2_total = np.sum(np.multiply(movement2, Direction[2:])) # Final position of the movement 2
#
#  <br>   else:
#         print(f'Input displacement vector is not valid. Make sure that the vector shape is ({eagle_form},)')
#
#     return velocity_total, movement1_total, movement2_total # return value of the function under conditional statement
#
#
# Note: in your lab report, the equation should also be included as a part of the discussion. DO NOT insert the function as a picture, rather, insert it as an MS Equation. For equations in jupyter notebooks, it should be in  LaTeX .

# %%
'''
GRADED FUNCTION 3 (50 points)
This is the starter code that you would use for Bebang's project. You may use Part 1 as a reference to complete this code.
Please provide proper documentation, commenting, and necessary revisions to make the code clean and understandable.
'''
## START OF FUNCTION
def month_profit_trace(profit, reach, make_figs=True): ## You can simplify/ optimize this code for extra points
    if (profit.shape == (4,)) and (reach.shape == (4,)): 
        week1 = np.array((reach[0], profit[0]))       
        week2 = np.array((reach[1], profit[1])) 
        week3 = np.array((reach[2], profit[2])) 
        week4 = np.array((reach[3], profit[3])) 
        
    
        week_total = week1 + week2 + week3 + week4   # Code for getting the resultant
        week_performance = np.linalg.norm(week_total) # Code for getting the performance_week
        alpha = 10**-6
        reach_gradient = np.arctan((week_total[1])/(week_total[0] + alpha)) #code for getting the reach_gradient
        reach_gradient = np.degrees(reach_gradient)
        

        plt.figure(figsize=(16,5))
        plt.title('Bebang\'s Month Post Efficiency')
        plt.xlim(0,1.01*np.sum(reach))
        plt.ylim(-np.sum(np.abs(profit)),np.sum(np.abs(profit)))
        plt.xlabel('FB Post Reach Increment')
        plt.ylabel('Profit')
        plt.grid()
        n = 2
        
        
        #Plotting
        plt.quiver(0,0, week1[0], week1[1], 
                   angles='xy', scale_units='xy',scale=1, color='green', width=0.0025,
                   label='Week 1: {:.2f}'.format(np.linalg.norm(week1)))
        
        plt.quiver(week1[0], week1[1], week2[0], week2[1],
                   angles='xy', scale_units='xy',scale=1, color='red', width=0.0025,
                   label='Week 2: {:.2f}'.format(np.linalg.norm(week2)))
        
        plt.quiver(np.add(week1[0],week2[0]), np.add(week1[1],week2[1]),week3[0], week3[1], 
                   angles='xy', scale_units='xy',scale=1, color='blue', width=0.0025,
                   label='Week 3: {:.2f}'.format(np.linalg.norm(week3)))
      
        plt.quiver((week1[0]+week2[0]+week3[0]),(week1[1]+week2[1]+week3[1]), week4[0], week4[1],
                   angles='xy', scale_units='xy', scale=1, color='violet', width=0.0025,
                   label='Week 4: {:.2f}'.format(np.linalg.norm(week4)))
       
       
        plt.quiver(0,0, week_total[0], week_total[1], 
                    angles='xy', scale_units='xy',scale=1, color='orange', width=0.005,
                    label='Efficiency: {:.2f} @ {:.2f}'.format(week_performance, reach_gradient))


        plt.legend(loc='upper left')

        if make_figs:
            plt.savefig(f'LinAlg-Lab2-Bebang Post Eff-{int(week_performance)}@{int(reach_gradient)}.png', dpi=300)

        plt.show()
    
    else:
        print("The needed value are not yet met to get this month's efficiency") ## Make a more appropriate error statement.

# %%
profit= np.array([500, -400, 850, -700])    ## You can change the values to make different scenarios
reach = np.array([500, -250, 1500,1000])             ## You can change the values to make different scenarios

month_profit_trace(profit, reach, make_figs=False) ## Toggle 'make_figs' during debugging or making documentations

# %% [markdown]
# **Guide questions:**
#    1. What is the relationship between the FB post reach and the profit?
#     <br> The relationship between the FB post reach and the profit is to know if getting a high number on FB post reach will have an effect to the profit of Bebang's project. <br>
#
# 2. Why is profit in the y-axis and FB post reach on the x-axis and not the other way around?
#     <br> The reason why the profit is in the y-axis and the FB post reach in the x-axis because in plotting the dependent variable is on the y-axis and the independent variable is on the x-axis. Since were looking for the efficiency based on the FB post reach increment, it will be the independent variable where you can control the value of it. And the profit is co-dependent on the result of it.
#
# 3. Kindly explain the process of plotting the post efficiency vectors.
#     <br> The process of plotting here is the same with PH Eagle Tracker because its the base code. The array of the vector per were set from 0-4. After inputting the values for profit and the reach post count, the function will be called and the computations for the plot will begin and finish with producing the output visually with vectors.
#
# 4. Provide a necessary equations that are representative to finding the  performanceweek  and  reachgradient .
#     <br> $$ performanceweek = week1 + week2 + week3 + week4 $$ <br>
#     <br>     $$ reachgradient = \frac{week total(1)}{week total(0)+ \alpha}$$
#
#
# 5. Try to alter the 'reach' and 'profit' values to display different scenarios. Save at least 3 scenarios then append and discuss the figures in your report.
#
# 6. What can be observed and concluded with the behavior of the vectors with respect to post efficiency?
#     <br> The vectors act based on the values given, there should be 2 values for a vector to be plotted. The vectors were getting longer if the post efficiency is higher and effective while it gets shorter if not and sometimes it went backwards if the efficiency is really bad.

# %% [markdown]
# **References**
# <br> [1]KattamuriMeghnaCheck out this Author's contributed articles., KattamuriMeghna, &amp; Check out this Author's contributed articles. (2018, May 14). Python: Introduction to Matplotlib. Retrieved October 04, 2020, from https://www.geeksforgeeks.org/python-introduction-matplotlib/ <br>
# [2] Pyplot¶. (n.d.). Retrieved October 04, 2020, from https://matplotlib.org/api/pyplot_api.html
# <br> [3] Editors, T. (2010, November 08). What Are Vectors, and How Are They Used? Retrieved October 04, 2020, from https://www.scientificamerican.com/article/football-vectors/

# %% [markdown]
# **Kindly answer these questions on the conclusion section of your laboratory report.**
# 1. Enumerate and briefly discuss the functions you have used in the laboratory exercise, please cite their usage using their respective documentations. (min of 200 words)
#     <br> The libraries used are MathPlotlib and quiver. Mathplotlib is a library that used for visualization, for plotting 2D arrays[1]. While quiver is used as auto scaling for the vectors[2]. Next function used is the array where it holds the values of the eagle or the profit of the said problem. These values in arrays will be used to plot the vectors. While the numpy.linalg.norm() was used to form a matrix. By using plt.quiver function that will make the vector proportionate to the graph by auto scaling it. The plt.ylim() and plt.xlim() are used to set limits for the x and y axis. The function plt.xlabel() and plt.ylabel() were used to put label on the output with its corresponding axis. Another function used is the plt.grid() where the output will show grid besides the longtitude and langtitude of the graph. The function np.degrees(theta) was used to convert from radian to degrees. There are common function used among the three parts these are, plt.show() to display the figures, plt.savefigs() to save the figures and plt.legend() a function that holds the legends for the axis. There are multiple formulas used as a function to plot the vectors, these are the resultants, magnitude and theta.
#
#
#
# 2. How do vectors relate to real-life values? (min of 50 words)<br>
#     Vectors are like the visualization of our progress. There will be ups and down. The direction we can take can be anything and anywhere. We have this whole world like the graph for ourselves. Its a canvass where we could put our direction anywhere. We could start somewhere, end it there then start somewhere else. Sometimes what happened could meet but in the end the resultant of the vectors will show that we kept going no matter what and will connect and make sense after all.
#
# 3. Kindly give other examples of how vectors are used or other real-life situations that can be modeled using vectors? (min of 100 words and do proper citation) <br>
#     There are multiple uses of how vectors are used in real-life situations, just like in a compass, vectors were used to tell the direction digitally. Another thing is GPS. Vectors are being used as well when playing billiards. In playing billiards you used a stick to push a ball and aim it to fell in one of the pockets. While playing you will analyze how strong you will hit the ball and where should the ball be hitted and be aware the direction it will possibly take along with its obstacles to consider. If you want to predict what will happen when two objects come in contact, momentum vectors is the answer.If you understand how vectors work it will help you on how to play better in billiards.
